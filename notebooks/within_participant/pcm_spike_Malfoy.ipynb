# %%
import PcmPy as pcm
import numpy as np
import matplotlib.pyplot as plt
import globals as gl
import os
import warnings
from vis import pcm_spike

warnings.filterwarnings("ignore")

plt.style.use('default')

# %%
path = os.path.join(gl.baseDir, 'smp2', 'spikes', gl.pcmDir)
monkey = 'Malfoy'
cuePre = 0
cueIdx = 20
cuePost = 84
pertIdx = 114
pertPost = 134

recordings = {
    'PFC': [17, 18, 19, 20, 21, 22, 23, 24],
    'PMd': [19], #[17, 18, 19, 20, 21, 22, 23, 24, 29], #
    'M1': [25, 27, 28],
    'S1': [27] #[26, 27, 28],
}

# %%
from vis import plot_dissimilarities

roi = 'PFC'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=11.041400782551138, pval=1.0429630211358843e-09
# None: tval=-13.665746091782841, pval=1.6561611150857554e-20

# %%
roi = 'PMd'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)
plt.show()
# Out:
# None: tval=-15.924909743094412, pval=1.9126011723739673e-12
# None: tval=-22.059622259779808, pval=2.4729002832140114e-31

# %%
roi = 'M1'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=9.061601575772627, pval=2.5112220723900357e-08
# None: tval=-8.671168161926044, pval=2.4075162587887218e-12

# %%
roi = 'S1'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=-3.831069825499557, pval=0.0011269417414410982
# None: tval=4.174579116525056, pval=9.335720657389569e-05

# %%
roi = 'PFC'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots(1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 2.5

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=-7.9055724014120035, pval=1.0180748305141918e-08
# None: tval=-14.06011582254842, pval=1.7082877020433333e-11
# None: tval=-59.87774483495528, pval=4.1323707148515356e-23

# %%
roi = 'PMd'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 6

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=-76.55949356284799, pval=5.078305819807971e-35
# None: tval=-8.011302619729967, pval=1.6411657607982895e-07
# None: tval=-17.52979087848295, pval=3.4473627540733296e-13

# %%
roi = 'M1'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 6

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=-37.53963746543619, pval=3.8673891278203155e-26
# None: tval=-7.212392526473395, pval=7.53882256851086e-07
# None: tval=-14.264321678876637, pval=1.328583580059937e-11

# %%
roi = 'S1'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 4

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=-3.7786237793781035, pval=0.0007272231137302688
# None: tval=-6.154227698321322, pval=6.48201605491259e-06
# None: tval=-14.456373669240667, pval=1.0517263921743226e-11
