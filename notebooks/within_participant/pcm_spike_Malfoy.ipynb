# %%
import PcmPy as pcm
import numpy as np
import matplotlib.pyplot as plt
import globals as gl
import os
import warnings
from vis import pcm_spike

warnings.filterwarnings("ignore")

plt.style.use('default')

# %%
path = os.path.join(gl.baseDir, 'smp2', 'spikes', gl.pcmDir)
monkey = 'Malfoy'
cuePre = 0
cueIdx = 20
cuePost = 84
pertIdx = 114
pertPost = 134

recordings = {
    'PFC': [17, 18, 19, 20, 21, 22, 23, 24],
    'PMd': [17, 18, 19, 20, 21, 22, 23, 24, 29], #
    'M1': [25, 27, 28],
    'S1': [26, 27, 28],}

# %%
from vis import plot_dissimilarities

roi = 'PFC'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=-11.041400782551142, pval=1.0429630211358804e-09
# None: tval=13.665746091782838, pval=1.6561611150857788e-20

# %%
roi = 'PMd'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)
plt.show()
# Out:
# None: tval=4.6778278796895085, pval=0.00016392550718662087
# None: tval=12.051509754776339, pval=5.253666325154233e-18

# %%
roi = 'M1'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=-9.061601575772631, pval=2.511222072390027e-08
# None: tval=8.671168161926044, pval=2.4075162587887218e-12

# %%
roi = 'S1'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=0.8999405481628309, pval=0.37941701913111514
# None: tval=-7.775706617880059, pval=8.80709132920662e-11

# %%
roi = 'PFC'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots(1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 2.5

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=7.905572401412003, pval=1.0180748305141954e-08
# None: tval=14.060115822548415, pval=1.7082877020433394e-11
# None: tval=59.877744834955315, pval=4.132370714851477e-23

# %%
roi = 'PMd'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 6

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=43.45741427900833, pval=5.9572565752271245e-28
# None: tval=10.420253217377583, pval=2.7007489511871252e-09
# None: tval=20.205903970703552, pval=2.6434729089011166e-14

# %%
roi = 'M1'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 6

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=37.53963746543618, pval=3.8673891278203706e-26
# None: tval=7.212392526473394, pval=7.53882256851086e-07
# None: tval=14.26432167887664, pval=1.3285835800599369e-11

# %%
roi = 'S1'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 4

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=3.059156737459886, pval=0.0047419277250570465
# None: tval=5.598385050180856, pval=2.1270187953862927e-05
# None: tval=26.797699355393327, pval=1.4741488762453236e-16
