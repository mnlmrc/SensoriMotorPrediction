# %%
from AnatSearchlight import searchlight as sl
import SensoriMotorPrediction.globals as gl
import os
import numpy as np

# %%
sl_s = sl.load(os.path.join(gl.baseDir, 'smp2', gl.roiDir, f'subj103', 'searchlight.L.h5'))

# %%
np.nanmean(sl_s.radius)
# Out:
# np.float64(13.168124173429854)
