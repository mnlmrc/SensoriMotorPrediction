# %%
from vis import plot_flatmap_cortical_activation, plot_flatmap_cerebellar_activation
import os
import globals as gl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import nibabel as nb
import  numpy as np
import nitools as nt
from matplotlib.colors import LinearSegmentedColormap
import pyvista as pv
from statsmodels.stats.anova import AnovaRM
from scipy.stats import ttest_rel, ttest_1samp

import nitools as nt
plt.style.use('default')

# Define the updated function and test it on the provided file
def load_border_vertices_xml(filepath):
    vertices = []
    inside_vertices_block = False
    with open(filepath, 'r') as f:
        for line in f:
            line = line.strip()
            if "<Vertices>" in line:
                inside_vertices_block = True
                line = line.replace("<Vertices>", "")
            if inside_vertices_block:
                if "</Vertices>" in line:
                    line = line.replace("</Vertices>", "")
                    inside_vertices_block = False
                if line:
                    numbers = [int(x) for x in line.split()]
                    vertices.extend(numbers)
    return np.array(vertices)
# Out:
# Base directory found: /cifs/diedrichsen/data/SensoriMotorPrediction/
# Base directory: /cifs/diedrichsen/data/SensoriMotorPrediction/

# %%
fig, axs = plt.subplots(2, sharex=True, sharey=True, figsize=(4, 3))

axs[0].axhline(0, color='blue')
axs[0].stem(0, 1, linefmt='b-', )
axs[0].set_title('Nogo trials')
axs[0].vlines(5.5, 0, 1,  color='k', ls='--')
axs[0].text(2.75, .5, 'Cue on (5.5s)', ha='center', va='center')
axs[0].text(.1, 1, 'Planning regressors (5)', ha='left', va='top', color='blue')
axs[0].set_yticks([])

axs[1].axhline(0, color='blue')
axs[1].stem(0, 1, linefmt='b-')
axs[1].set_title('Go trials')
axs[1].axhline(0, color='red')
axs[1].stem(2.5, 1, linefmt='r-')
axs[1].vlines(5.5, 0, 1,  color='k', ls='--')
axs[1].set_yticks([])
axs[1].text(1.25, .5, 'Cue on (1.5-2.5s)', ha='center', va='center')
axs[1].text(4, .5, 'Stimulation on (3s)', ha='center', va='center')
axs[1].text(2.6, 1, 'Execution regressors (8)', ha='left', va='top', color='red')
axs[1].set_xlabel('Time (s)')

fig.suptitle(f'GLM 12 design')
fig.tight_layout()

# %%
fig, axs = plt.subplots(2, sharex=True, sharey=True, figsize=(4, 3))

axs[0].axhline(0, color='blue')
axs[0].stem(0, 1, linefmt='b-', )
axs[0].set_title('Nogo trials')
axs[0].vlines(5.5, 0, 1,  color='k', ls='--')
axs[0].text(2.75, .5, 'Cue on (5.5s)', ha='center', va='center')
axs[0].text(.1, 1, 'Planning regressors (5)', ha='left', va='top', color='blue')
axs[0].set_yticks([])

axs[1].axhline(0, color='blue')
axs[1].set_title('Go trials')
axs[1].axhline(0, color='red')
axs[1].stem(2.5, 1, linefmt='r-')
axs[1].vlines(5.5, 0, 1,  color='k', ls='--')
axs[1].set_yticks([])
axs[1].text(1.25, .5, 'Cue on (1.5-2.5s)', ha='center', va='center')
axs[1].text(4, .5, 'Stimulation on (3s)', ha='center', va='center')
axs[1].text(2.6, 1, 'Execution regressor (1)', ha='left', va='top', color='red')
axs[1].set_xlabel('Time (s)')

fig.suptitle(f'GLM 14 design')
fig.tight_layout()

# %%
experiment = 'smp2'
glm = 12
dtype = 'con'
H = 'L'

# Define colors with non-uniform positions to steepen the extremities
colors = [
    (0.0, '#000080'),   # Navy
    (0.5, 'white'),    # Symmetric midpoint
    (1.0, '#FF7F7F')    # Saturated peach
]

# Create custom colormap with steeper outer transitions
cmap = LinearSegmentedColormap.from_list('steep_navy_peach', colors)

cifti = nb.load(os.path.join(gl.baseDir, experiment, gl.wbDir, f'glm{glm}.{dtype}.plan-exec.smooth.dscalar.nii'))
column_names = cifti.header.get_axis(0).name
giftis = nt.split_cifti_to_giftis(cifti, type='func', column_names=column_names)

p = pv.Plotter(window_size=(600, 600))

# for h, H in enumerate(Hem):

surf = nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.{H}.very_inflated.surf.gii')
coords = surf.darrays[0].data
faces = surf.darrays[1].data.astype(np.uint32)  # pyvista requires uint32
data = nt.get_gifti_data_matrix(giftis[0])[:, 1]
faces = np.hstack([np.full((faces.shape[0], 1), 3), faces]).astype(np.int32).flatten()

sulc = nt.get_gifti_data_matrix(nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.LR.sulc.dscalar.gii'))
if H=='L':
    sulc = sulc[:len(data)]
else:
    sulc = sulc[len(data):]

# Now create the mesh
mesh = pv.PolyData(coords, faces)
mesh.point_data["overlay"] = data

mesh.point_data["sulc"] = sulc

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-IPS.border")
borderIPS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-CS.border")
borderCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-PoCS.border")
borderPoCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-SF.border")
borderSF = coords[border_verts]

p.add_mesh(mesh, scalars="sulc", cmap="Greys", clim=[-2, 2], lighting=True, show_scalar_bar=False)
p.add_mesh(mesh, scalars="overlay", cmap=cmap, clim=[-10, 10], lighting=True, show_scalar_bar=False)
p.add_scalar_bar(title="activation (a.u.)",
             n_labels=3,                 # Show fewer ticks
             vertical=False,            # Horizontal layout
             color='w',
             shadow=True,
             fmt="%.0f",
             position_x=0.3,  # Centered horizontally (0 = left, 1 = right)
             position_y=0.05, # Lower position (closer to bottom of figure)
             width=0.4,       # Proportion of figure width
             height=0.04)
p.add_points(borderCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderPoCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderIPS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderSF[::3], color='k', point_size=6, render_points_as_spheres=True)

p.set_background("white")
p.view_vector((-1, 0, .5))        # start from a good view
 # dorsal view


p.show()
# Out:
# /home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:36: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
experiment = 'smp2'
glm = 12
dtype = 'con'
H = 'R'

# Define colors with non-uniform positions to steepen the extremities
colors = [
    (0.0, '#000080'),   # Navy
    (0.5, 'white'),    # Symmetric midpoint
    (1.0, '#FF7F7F')    # Saturated peach
]

# Create custom colormap with steeper outer transitions
cmap = LinearSegmentedColormap.from_list('steep_navy_peach', colors)

cifti = nb.load(os.path.join(gl.baseDir, experiment, gl.wbDir, f'glm{glm}.{dtype}.plan-exec.smooth.dscalar.nii'))
column_names = cifti.header.get_axis(0).name
giftis = nt.split_cifti_to_giftis(cifti, type='func', column_names=column_names)

p = pv.Plotter(window_size=(600, 600))

# for h, H in enumerate(Hem):

surf = nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.{H}.very_inflated.surf.gii')
coords = surf.darrays[0].data
faces = surf.darrays[1].data.astype(np.uint32)  # pyvista requires uint32
data = nt.get_gifti_data_matrix(giftis[1])[:, 1]
faces = np.hstack([np.full((faces.shape[0], 1), 3), faces]).astype(np.int32).flatten()

sulc = nt.get_gifti_data_matrix(nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.LR.sulc.dscalar.gii'))
if H=='L':
    sulc = sulc[:len(data)]
else:
    sulc = sulc[len(data):]

# Now create the mesh
mesh = pv.PolyData(coords, faces)
mesh.point_data["overlay"] = data

mesh.point_data["sulc"] = sulc

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-IPS.border")
borderIPS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-CS.border")
borderCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-PoCS.border")
borderPoCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-SF.border")
borderSF = coords[border_verts]

p.add_mesh(mesh, scalars="sulc", cmap="Greys", clim=[-2, 2], lighting=True, show_scalar_bar=False)
p.add_mesh(mesh, scalars="overlay", cmap=cmap, clim=[-10, 10], lighting=True, show_scalar_bar=False)
p.add_scalar_bar(title="activation (a.u.)",
             n_labels=3,                 # Show fewer ticks
             vertical=False,            # Horizontal layout
             color='w',
             shadow=True,
             fmt="%.0f",
             position_x=0.3,  # Centered horizontally (0 = left, 1 = right)
             position_y=0.05, # Lower position (closer to bottom of figure)
             width=0.4,       # Proportion of figure width
             height=0.04)
p.add_points(borderCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderPoCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderIPS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderSF[::3], color='k', point_size=6, render_points_as_spheres=True)

p.set_background("black")
p.view_vector((1, 0, .5))        # start from a good view
 # dorsal view


p.show()
# Out:
# /home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:36: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
import pyvista as pv
import nibabel as nb
import numpy as np
import os
import globals as gl
import nitools as nt

experiment = 'smp2'
glm = 12
dtype = 'con'
H = 'L'

cifti = nb.load(os.path.join(gl.baseDir, experiment, gl.wbDir, f'glm{glm}.{dtype}.plan-exec.smooth.dscalar.nii'))
column_names = cifti.header.get_axis(0).name
giftis = nt.split_cifti_to_giftis(cifti, type='func', column_names=column_names)

p = pv.Plotter(window_size=(600, 600))

# for h, H in enumerate(Hem):

surf = nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.{H}.very_inflated.surf.gii')
coords = surf.darrays[0].data
faces = surf.darrays[1].data.astype(np.uint32)  # pyvista requires uint32
data = nt.get_gifti_data_matrix(giftis[0])[:, 0]
faces = np.hstack([np.full((faces.shape[0], 1), 3), faces]).astype(np.int32).flatten()

sulc = nt.get_gifti_data_matrix(nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.LR.sulc.dscalar.gii'))
if H=='L':
    sulc = sulc[:len(data)]
else:
    sulc = sulc[len(data):]

# Now create the mesh
mesh = pv.PolyData(coords, faces)
mesh.point_data["overlay"] = data

mesh.point_data["sulc"] = sulc

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-IPS.border")
borderIPS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-CS.border")
borderCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-PoCS.border")
borderPoCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-SF.border")
borderSF = coords[border_verts]

p.add_mesh(mesh, scalars="sulc", cmap="Greys", clim=[-2, 2], lighting=True, show_scalar_bar=False)
p.add_mesh(mesh, scalars="overlay", cmap=cmap, clim=[-10, 10], lighting=True, show_scalar_bar=False)
p.add_scalar_bar(title="activation (a.u.)",
             n_labels=3,                 # Show fewer ticks
             vertical=False,            # Horizontal layout
             color='w',
             shadow=True,
             fmt="%.0f",
             position_x=0.3,  # Centered horizontally (0 = left, 1 = right)
             position_y=0.05, # Lower position (closer to bottom of figure)
             width=0.4,       # Proportion of figure width
             height=0.04)
p.add_points(borderCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderPoCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderIPS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderSF[::3], color='k', point_size=6, render_points_as_spheres=True)

p.set_background("black")
p.view_vector((-1, 0, .5))        # start from a good view
 # dorsal view


p.show()
# Out:
# /home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:36: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
import pyvista as pv
import nibabel as nb
import numpy as np
import os
import globals as gl
import nitools as nt

experiment = 'smp2'
glm = 12
dtype = 'con'
H = 'R'

cifti = nb.load(os.path.join(gl.baseDir, experiment, gl.wbDir, f'glm{glm}.{dtype}.plan-exec.smooth.dscalar.nii'))
column_names = cifti.header.get_axis(0).name
giftis = nt.split_cifti_to_giftis(cifti, type='func', column_names=column_names)

p = pv.Plotter(window_size=(600, 600))

# for h, H in enumerate(Hem):

surf = nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.{H}.very_inflated.surf.gii')
coords = surf.darrays[0].data
faces = surf.darrays[1].data.astype(np.uint32)  # pyvista requires uint32
data = nt.get_gifti_data_matrix(giftis[1])[:, 0]
faces = np.hstack([np.full((faces.shape[0], 1), 3), faces]).astype(np.int32).flatten()

sulc = nt.get_gifti_data_matrix(nb.load(f'/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.LR.sulc.dscalar.gii'))
if H=='L':
    sulc = sulc[:len(data)]
else:
    sulc = sulc[len(data):]

# Now create the mesh
mesh = pv.PolyData(coords, faces)
mesh.point_data["overlay"] = data

mesh.point_data["sulc"] = sulc

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-IPS.border")
borderIPS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-CS.border")
borderCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-PoCS.border")
borderPoCS = coords[border_verts]

border_verts = load_border_vertices_xml("/cifs/diedrichsen/data/Atlas_templates/fs_LR_32/fs_LR.32k.L.border-SF.border")
borderSF = coords[border_verts]

p.add_mesh(mesh, scalars="sulc", cmap="Greys", clim=[-2, 2], lighting=True, show_scalar_bar=False)
p.add_mesh(mesh, scalars="overlay", cmap=cmap, clim=[-10, 10], lighting=True, show_scalar_bar=False)
p.add_scalar_bar(title="activation (a.u.)",
             n_labels=3,                 # Show fewer ticks
             vertical=False,            # Horizontal layout
             color='w',
             shadow=True,
             fmt="%.0f",
             position_x=0.3,  # Centered horizontally (0 = left, 1 = right)
             position_y=0.05, # Lower position (closer to bottom of figure)
             width=0.4,       # Proportion of figure width
             height=0.04)
p.add_points(borderCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderPoCS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderIPS[::3], color='k', point_size=6, render_points_as_spheres=True)
p.add_points(borderSF[::3], color='k', point_size=6, render_points_as_spheres=True)

p.set_background("black")
p.view_vector((1, 0, .5))        # start from a good view
 # dorsal view


p.show()
# Out:
# /home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:36: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/UWO/memanue5/Documents/GitHub/sensori-motor-prediction/venv/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
# plt.style.use('default')
#
# glm = 14
# experiment='smp2'
# dtype = 'con'
#
# img = os.path.join(gl.baseDir, experiment, gl.wbDir, f'glm{glm}.{dtype}.smooth.dscalar.nii')
#
# fig, axs = plot_flatmap_cortical_activation(img, vmin=-8, vmax=8, figsize=(6, 6), frame=(.16, .12, .68, .8), rounding=0, cbar_fraction=.01)
#
# fig.suptitle(f'Average activation vs. baseline')
# fig.subplots_adjust(top=0.85, bottom=.1, wspace=0, hspace=0.1, right=.9, left=0)
#
# plt.show()

# %%
glm = 12
experiment = 'smp2'
rois = ['SMA', 'PMd', 'PMv', 'M1', 'S1', 'SPLa', 'SPLp', 'V1']
H = 'L'
conditions = list(gl.regressor_mapping.keys())[0:13]

df_con = pd.read_csv(os.path.join(gl.baseDir, experiment, f'glm{glm}','ROI.con.avg.tsv'), sep='\t')
df_con['sn'] = df_con['sn'].astype(str)
df_con = df_con[df_con['condition'].isin(conditions)]
df_con['epoch'] = 'planning'
mask = df_con['condition'].str.contains('index') | df_con['condition'].str.contains('ring')
df_con.loc[mask, 'epoch'] = 'execution'

df_con_stat = df_con.groupby(['sn', 'roi', 'Hem', 'epoch']).mean(numeric_only=True).reset_index()

fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(12, 3))

for r, roi in enumerate(rois):

    ax = axs[r]

    sns.barplot(df_con[(df_con['roi'] == roi) & (df_con['Hem'] == H)],
                ax=ax,
                y='con',
                x='condition',
                order=conditions,
                palette=[gl.colour_mapping[cond] for cond in conditions],
                # showfliers=False,
                errorbar='se',
                width=1,
                legend=False
                )

    ax.axhline(0, ls='-', color='k', lw=.8)
    ax.set_title(roi)
    ax.set_ylabel('')
    ax.set_xlabel('')
    ax.tick_params(axis='x', labelbottom=False, width=0)

    ax.spines[['left', 'top', 'right', 'bottom']].set_visible(False)
    ax.tick_params(axis='y',width=0)
    if r==0:
        ax.spines[['left',]].set_visible(True)
        ax.spines[['left',]].set_linewidth(2)
        ax.tick_params(axis='y',width=2)
        ax.spines[['left',]].set_bounds(0, 20)

    plan = df_con_stat[(df_con_stat['roi'] == roi) & (df_con_stat['Hem'] == H) & (df_con_stat['epoch'] == 'planning')]['con']
    exec = df_con_stat[(df_con_stat['roi'] == roi) & (df_con_stat['Hem'] == H) & (df_con_stat['epoch'] == 'execution')]['con']

    print(f'ROI: {roi}')
    print(f'planning vs. execution: {ttest_rel(exec, plan)}')
    print(f'planning vs. 0: {ttest_1samp(plan, 0)}')
    print(f'execution vs. 0: {ttest_1samp(exec, 0)}')

fig.supylabel('activation (a.u.)')
fig.suptitle(f'Average activation')
fig.tight_layout()
# Out:
# ROI: SMA
# planning vs. execution: TtestResult(statistic=np.float64(0.7975754190995864), pvalue=np.float64(0.4394428399206982), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(3.1080486565001983), pvalue=np.float64(0.008316910784052675), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(3.5174613945170004), pvalue=np.float64(0.0037851880575500195), df=np.int64(13))
# ROI: PMd
# planning vs. execution: TtestResult(statistic=np.float64(0.47671588147634797), pvalue=np.float64(0.641477915919705), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(3.96429311178293), pvalue=np.float64(0.0016173310554559624), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(4.372142232212655), pvalue=np.float64(0.0007554753038535601), df=np.int64(13))
# ROI: PMv
# planning vs. execution: TtestResult(statistic=np.float64(0.6463225237815314), pvalue=np.float64(0.5293160421832426), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(2.6232003954563696), pvalue=np.float64(0.02105771759873256), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(3.5269597440205054), pvalue=np.float64(0.0037169064052107567), df=np.int64(13))
# ROI: M1
# planning vs. execution: TtestResult(statistic=np.float64(3.178661627544139), pvalue=np.float64(0.007259782104720714), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(2.5166356418819826), pvalue=np.float64(0.025767168762279528), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(7.928164696778887), pvalue=np.float64(2.467923801495127e-06), df=np.int64(13))
# ROI: S1
# planning vs. execution: TtestResult(statistic=np.float64(6.365437552961251), pvalue=np.float64(2.474550854438578e-05), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(-0.42022169662535885), pvalue=np.float64(0.6811861787468663), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(10.463829639839252), pvalue=np.float64(1.0605823328305948e-07), df=np.int64(13))
# ROI: SPLa
# planning vs. execution: TtestResult(statistic=np.float64(1.5675249577985706), pvalue=np.float64(0.14100238721738248), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(2.06062913890841), pvalue=np.float64(0.05993599725085745), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(4.362951659851555), pvalue=np.float64(0.0007683975281814326), df=np.int64(13))
# ROI: SPLp
# planning vs. execution: TtestResult(statistic=np.float64(1.6020447680499719), pvalue=np.float64(0.13315519621399569), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(1.5866732089069888), pvalue=np.float64(0.136601705896288), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(3.7701416537282006), pvalue=np.float64(0.002336221848123279), df=np.int64(13))
# ROI: V1
# planning vs. execution: TtestResult(statistic=np.float64(2.0005575995568443), pvalue=np.float64(0.0667736492615635), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(-0.45340393485484676), pvalue=np.float64(0.6577336264754934), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(2.920539026160677), pvalue=np.float64(0.011928152031005376), df=np.int64(13))

# %%
glm = 12
experiment = 'smp2'
rois = ['SMA', 'PMd', 'PMv', 'M1', 'S1', 'SPLa', 'SPLp', 'V1']
H = 'R'
conditions = list(gl.regressor_mapping.keys())[0:13]

df_con = pd.read_csv(os.path.join(gl.baseDir, experiment, f'glm{glm}','ROI.con.avg.tsv'), sep='\t')
df_con['sn'] = df_con['sn'].astype(str)
df_con = df_con[df_con['condition'].isin(conditions)]
df_con['epoch'] = 'planning'
mask = df_con['condition'].str.contains('index') | df_con['condition'].str.contains('ring')
df_con.loc[mask, 'epoch'] = 'execution'

df_con_stat = df_con.groupby(['sn', 'roi', 'Hem', 'epoch']).mean(numeric_only=True).reset_index()

fig, axs = plt.subplots(1, len(rois), sharey=True, sharex=True, figsize=(12, 3))

for r, roi in enumerate(rois):

    ax = axs[r]

    sns.barplot(df_con[(df_con['roi'] == roi) & (df_con['Hem'] == H)],
                ax=ax,
                y='con',
                x='condition',
                order=conditions,
                palette=[gl.colour_mapping[cond] for cond in conditions],
                # showfliers=False,
                errorbar='se',
                width=1,
                legend=False
                )

    ax.axhline(0, ls='-', color='k', lw=.8)
    ax.set_title(roi)
    ax.set_ylabel('')
    ax.set_xlabel('')
    ax.tick_params(axis='x', labelbottom=False, width=0)

    ax.spines[['left', 'top', 'right', 'bottom']].set_visible(False)
    ax.tick_params(axis='y',width=0)
    if r==0:
        ax.spines[['left',]].set_visible(True)
        ax.spines[['left',]].set_linewidth(2)
        ax.tick_params(axis='y',width=2)
        ax.spines[['left',]].set_bounds(0, 20)

    plan = df_con_stat[(df_con_stat['roi'] == roi) & (df_con_stat['Hem'] == H) & (df_con_stat['epoch'] == 'planning')]['con']
    exec = df_con_stat[(df_con_stat['roi'] == roi) & (df_con_stat['Hem'] == H) & (df_con_stat['epoch'] == 'execution')]['con']

    print(f'ROI: {roi}')
    print(f'planning vs. execution: {ttest_rel(plan, exec)}')
    print(f'planning vs. 0: {ttest_1samp(plan, 0)}')
    print(f'execution vs. 0: {ttest_1samp(exec, 0)}')

fig.supylabel('activation (a.u.)')
fig.suptitle(f'Average activation')
fig.tight_layout()
# Out:
# ROI: SMA
# planning vs. execution: TtestResult(statistic=np.float64(-0.9069764121691518), pvalue=np.float64(0.3809239102585319), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(2.9806490039736007), pvalue=np.float64(0.010627037334196138), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(3.207159053969894), pvalue=np.float64(0.0068722204459720415), df=np.int64(13))
# ROI: PMd
# planning vs. execution: TtestResult(statistic=np.float64(-0.8738502600172671), pvalue=np.float64(0.3980553663084173), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(3.006077638140923), pvalue=np.float64(0.010119921927688215), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(2.692980879130135), pvalue=np.float64(0.01843907041915967), df=np.int64(13))
# ROI: PMv
# planning vs. execution: TtestResult(statistic=np.float64(-1.2104565439048194), pvalue=np.float64(0.2476526278198723), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(1.4673045724783735), pvalue=np.float64(0.1660659992251343), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(2.6114424027739127), pvalue=np.float64(0.02153322864461901), df=np.int64(13))
# ROI: M1
# planning vs. execution: TtestResult(statistic=np.float64(-1.035952138527559), pvalue=np.float64(0.3191112852743817), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(0.3355751635804422), pvalue=np.float64(0.7425451419376448), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(1.8312852724820037), pvalue=np.float64(0.0900650555462416), df=np.int64(13))
# ROI: S1
# planning vs. execution: TtestResult(statistic=np.float64(-1.9565671731013938), pvalue=np.float64(0.07222852247631377), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(-1.2695806358440735), pvalue=np.float64(0.2264910578213453), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(2.2807360095962523), pvalue=np.float64(0.04006432397653916), df=np.int64(13))
# ROI: SPLa
# planning vs. execution: TtestResult(statistic=np.float64(-1.2265409850152078), pvalue=np.float64(0.24174743623638864), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(1.2320534206484304), pvalue=np.float64(0.2397492938754643), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(2.4398791041057186), pvalue=np.float64(0.029773662701379343), df=np.int64(13))
# ROI: SPLp
# planning vs. execution: TtestResult(statistic=np.float64(-2.1456606375384295), pvalue=np.float64(0.051361615244445144), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(0.0003431818816914486), pvalue=np.float64(0.9997313908728773), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(3.5000412115824324), pvalue=np.float64(0.003913736776584248), df=np.int64(13))
# ROI: V1
# planning vs. execution: TtestResult(statistic=np.float64(-1.6374750769611077), pvalue=np.float64(0.1254968136096471), df=np.int64(13))
# planning vs. 0: TtestResult(statistic=np.float64(-0.36721375866036027), pvalue=np.float64(0.7193680994240224), df=np.int64(13))
# execution vs. 0: TtestResult(statistic=np.float64(2.5406895506401233), pvalue=np.float64(0.02462238085590855), df=np.int64(13))
