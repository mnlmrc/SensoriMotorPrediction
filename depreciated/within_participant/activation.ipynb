# %%
from Plot import plot_flatmap_cortical_activation
import os
import globals as gl
import matplotlib.pyplot as plt
plt.style.use('default')
# Out:
# Base directory found: /cifs/diedrichsen/data/SensoriMotorPrediction/
# Base directory: /cifs/diedrichsen/data/SensoriMotorPrediction/

# %%
glm = 12
experiment = 'smp2'
dtype = 'con'

# %%
sn = 111

img = os.path.join(gl.baseDir, experiment, gl.wbDir, f'subj{sn}', f'glm{glm}.{dtype}.dscalar.nii')

fig, axs = plot_flatmap_cortical_activation(img)

fig.suptitle(f'Average activation vs. baseline (participant {sn})')
fig.subplots_adjust(top=0.85, bottom=.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 sn = 111
#       3 img = os.path.join(gl.baseDir, experiment, gl.wbDir, f'subj{sn}', f'glm{glm}.{dtype}.dscalar.nii')
# ----> 5 fig, axs = plot_flatmap_cortical_activation(img)
#       7 fig.suptitle(f'Average activation vs. baseline (participant {sn})')
#       8 fig.subplots_adjust(top=0.85, bottom=.2)
#
# File ~/Documents/GitHub/sensori-motor-prediction/Plot.py:106, in plot_flatmap_cortical_activation(img, vmin, vmax, xlim, ylim, figsize, frame, rounding, cbar_orientation, cbar_fraction)
#     104 for artist in ax.get_children():
#     105     if hasattr(artist, 'set_clip_path'):
# --> 106         artist.set_clip_path(bbox)
#     108 im = np.array([x in exec_col_names for x in col_names])
#     109 darray_avg = np.array(darray[:, im]).mean(axis=1)
#
# ...
