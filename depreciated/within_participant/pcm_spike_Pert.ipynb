# %%
import PcmPy as pcm
import numpy as np
import matplotlib.pyplot as plt
import globals as gl
import os
import warnings
from vis import pcm_spike

warnings.filterwarnings("ignore")

plt.style.use('default')
# Out:
# Base directory found: /cifs/diedrichsen/data/SensoriMotorPrediction/
# Base directory: /cifs/diedrichsen/data/SensoriMotorPrediction/

# %%
path = os.path.join(gl.baseDir, 'smp2', 'spikes', gl.pcmDir)
monkey = 'Pert'
cuePre = 0
cueIdx = 20
cuePost = 84
pertIdx = 114
pertPost = 134

recordings = {
    'PFC': [8, 9],
    'preSMA': [17, 18],
    'SMA': [16, 17, 18],
    'PMd': [4, 5, 6, 7],
    'M1': [3, 14],
    'S1': [13, ],
    'VPL': [19, ]}

# %%
from vis import plot_dissimilarities

roi = 'PFC'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=1.2414171978990236, pval=0.2295598429527835
# None: tval=9.112956015983022, pval=4.130519032253866e-13

# %%
roi = 'preSMA'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=13.425002571048221, pval=3.808324461912285e-11
# None: tval=10.934660969573375, pval=3.4153690806750243e-16

# %%
roi = 'SMA'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=2.325925894930883, pval=0.031244209078908788
# None: tval=9.872111563213085, pval=2.0648659523852415e-14

# %%
roi = 'PMd'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)
plt.show()
# Out:
# None: tval=5.012379947161538, pval=7.733273642555786e-05
# None: tval=10.899936197777212, pval=3.8978604109593437e-16

# %%
roi = 'M1'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=-1.6624322038760557, pval=0.11283565463081129
# None: tval=6.4033134383694925, pval=2.164139211635936e-08

# %%
roi = 'S1'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=2.3349109521736513, pval=0.030671539619203825
# None: tval=6.32694097222443, pval=2.9290063943324175e-08

# %%
roi = 'VPL'
epoch = 'plan'
rec = recordings[roi]

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(3, 2.5))

vmin, vmax = 0, 3

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[:cueIdx], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[cueIdx:cuePost], list(gl.regressor_mapping.keys())[:5], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.025)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})
_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-.1, 3)
axs[0].spines['left'].set_bounds(0, 3)

plt.show()
# Out:
# None: tval=-9.347431789604792, pval=1.5430653013488824e-08
# None: tval=7.951583489597715, pval=4.336109909593968e-11

# %%
roi = 'PFC'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots(1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 2.5

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=5.052735667812635, pval=2.1907431689217104e-05
# None: tval=15.543162964043397, pval=2.9392724900019646e-12
# None: tval=12.924297862639119, pval=7.326142512402122e-11

# %%
roi = 'preSMA'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots(1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 2

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=16.46669500972836, pval=2.957315144455196e-16
# None: tval=11.393358036743402, pval=6.190495556834222e-10
# None: tval=42.88931922455569, pval=2.238712501420941e-20

# %%
from vis import plot_theta_lfp, plot_theta_lfp_mean

roi = 'SMA'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots(1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 5

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=47.68702700726148, pval=4.177690548266423e-29
# None: tval=7.1008839996608195, pval=9.390581745330551e-07
# None: tval=8.89522621924711, pval=3.349579647840386e-08

# %%
roi = 'PMd'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 5

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=27.305208601923198, pval=3.0767763947207327e-22
# None: tval=8.832687624761295, pval=3.735949970859741e-08
# None: tval=25.659697444062648, pval=3.2918622996915714e-16

# %%
roi = 'M1'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 10

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=16.35002951543132, pval=3.5646595718130176e-16
# None: tval=8.490835765576746, pval=6.844399478542042e-08
# None: tval=27.07622360755396, pval=1.2170098021289643e-16

# %%
roi = 'S1'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots( 1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 10

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=17.510815291425804, pval=5.82264560842508e-17
# None: tval=9.595463699896891, pval=1.019280259505716e-08
# None: tval=13.216343078443892, pval=4.989757337842829e-11

# %%
roi = 'VPL'
epoch = 'exec'
rec = recordings[roi]

fig, axs = plt.subplots(1, 3, sharex='col', sharey=True, figsize=(5, 2.5))

vmin, vmax = 0, 6

G_obs = []
for r in rec:
    G_obs.append(np.load(os.path.join(path, f'G_obs.spike.{monkey}.{roi}.aligned.{epoch}-{r}.npy')))
G_obs = np.array(G_obs).mean(axis=0)
fig, axs = plot_dissimilarities(fig, axs, 0, G_obs[cuePost:pertIdx], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 1, G_obs[pertIdx:pertPost], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
fig, axs = plot_dissimilarities(fig, axs, 2, G_obs[pertPost:], list(gl.regressor_mapping.keys())[5:13], vmin=vmin, vmax=vmax, sqrt=True,)
cax = axs[-1].get_images()[0]
cbar = fig.colorbar(cax, ax=axs, orientation='vertical', fraction=.015)
cbar.set_label('dissimilarity (a.u.)')
axs[0].set_title('Pre')
axs[1].set_title('Post early')
axs[2].set_title('Post late')

fig.suptitle(f'Dissimilarities between\nspiking patterns (monkey {monkey[0]}, {roi})')

fig, axs = plt.subplots(1, 2, sharex='col', sharey=True, figsize=(5, 3), gridspec_kw={'width_ratios': [3, .5]})

_, axs = pcm_spike(fig, axs, roi, epoch, monkey, rec)
axs[0].set_ylim(-1, 18)
axs[0].spines['left'].set_bounds(0, 15)

plt.show()
# Out:
# None: tval=27.056193815791953, pval=3.9743216079356123e-22
# None: tval=8.085623982860339, pval=1.4303163305053893e-07
# None: tval=45.342334998818274, pval=7.857598590546879e-21
